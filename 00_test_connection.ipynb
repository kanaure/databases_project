# %%
# !pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 23.8 MB/s  0:00:00 eta 0:00:01
# ...

# %%
import sys
sys.path.append('..')  # So notebooks can import config.py from parent directory

from config import engine, test_connection

# %%
# Cell 1
import sys
sys.path.append('..')  # So notebooks can import config.py from parent directory

from config import engine, test_connection

# Cell 2
test_connection()
# Out:
# ✓ Database connection successful!
# True
